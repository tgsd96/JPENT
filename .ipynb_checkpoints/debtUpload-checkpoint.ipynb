# %%
import pandas as pd

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://tushargarg:colgate@localhost/jpent')

# %%
tally = pd.read_excel('list1908.xlsx',sheet_name='Sheet1')

# %%
tally = tally.fillna('')

# %%
newBalance = tally.iloc[:,[0,1]]

# %%
newBalance.head()
# Out:
#                                         Name Beat
# 0                            9 TO 9 MARCETOS  SUN
# 1                               A.K. TRADERS  SAT
# 2  AARADHYA CANTEEN STATIONARY AND FOOD MART  TUE
# 3    AARADHYA CANTEEN STATIONERY & FOOD MART  TUE
# 4                                 ADYA STORE  SAT

# %%
newBalance = newBalance.fillna('')

# %%
newBalance
# Out:
#                                           Name Beat
# 0                              9 TO 9 MARCETOS  SUN
# 1                                 A.K. TRADERS  SAT
# 2    AARADHYA CANTEEN STATIONARY AND FOOD MART  TUE
# 3      AARADHYA CANTEEN STATIONERY & FOOD MART  TUE
# 4                                   ADYA STORE  SAT
# 5                 AGGARAWAL DEPARTMENTAL STORE  TUE
# 6                    AGGARWAL DEPARTMENT STORE  SAT
# 7                          AGGARWAL FOOD PLAZA  THU
# 8           AGGARWAL KIRANA  AND GENERAL STORE  THU
# 9                        AGGARWAL KIRANA STORE  MON
# 10                    AGGARWAL PROVISION STORE  SAT
# 11                           AGGARWAL SWEETS .  OTH
# 12                         AGGARWAL TRADERS AI  THU
# 13                         AGGARWAL TRADING CO  TUE
# 14                             AGGAWAL TRADERS  THU
# 15                            ALAM ENTERPRISES  SUN
# 16                           AMIT TYAGI KIRANA  MON
# ...

# %%
newBalance[newBalance['Final']==0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Miniconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3063             try:
# -> 3064                 return self._engine.get_loc(key)
#    3065             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Final'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-2e43d7e0972a> in <module>()
# ----> 1 newBalance[newBalance['Final']==0]
#
# ...

# %%
result = engine.execute('select * from master_list')

# %%
newBalance
# Out:
#                                         Name  Final
# 0                            9 TO 9 MARCETOS      0
# 1                               A.K. TRADERS   1369
# 2    AARADHYA CANTEEN STATIONERY & FOOD MART  20189
# 3                                 ADYA STORE   3924
# 4               AGGARAWAL DEPARTMENTAL STORE  -2390
# 5                  AGGARWAL DEPARTMENT STORE   8668
# 6                        AGGARWAL FOOD PLAZA   1527
# 7         AGGARWAL KIRANA  AND GENERAL STORE      0
# 8                      AGGARWAL KIRANA STORE   2634
# 9                   AGGARWAL PROVISION STORE  27840
# 10                  AGGARWAL PROVISION STORE  16903
# 11                         AGGARWAL SWEETS .      0
# 12                       AGGARWAL TRADERS AI   6461
# 13                       AGGARWAL TRADING CO   3269
# 14                         AMIT TYAGI KIRANA      0
# 15                               AMRIT STORE   2042
# 16                            ANANT WELLNESS  27815
# ...

# %%
for row in newBalance.itertuples():
    name = row[1]
    sqlQuery = "SELECT cust_id from master_list where name='%s'"%name
    result = engine.execute(sqlQuery)
    cust_id = -1
    for r1 in result:
        cust_id = r1[0]
        break
    if cust_id == -1:
        print('Failure for name: %s'%name)
#     print(cust_id)
    debit = int(row[2])
    sqlInsert = "Insert into balance_sheet(cust_id, debit) values(%s,%s)"%(cust_id,debit)
    engine.execute(sqlInsert)

# %%
balance = dat

# %%
for row in newBalance.itertuples():
    name = row[1]
    sqlQuery = "SELECT cust_id from master_list where name='%s'"%name
    result = engine.execute(sqlQuery)
    cust_id = -1
    for r1 in result:
        cust_id = r1[0]
        break
    if cust_id == -1:
        print('Failure for name: %s'%name)
#     print(cust_id)
    beat = str(row[2])
    sqlInsert = "Update master_list set area = '%s' where cust_id='%s'"%(beat,cust_id)
#     print(sqlInsert)
    res = engine.execute(sqlInsert)
#     print(res)
#     for row in result:
#         print(row)
# Out:
# Failure for name: EVERYDAY SWEETS

# %%
for row in newBalance.itertuples():
    print(row[1],row[2])
# Out:
# 9 TO 9 MARCETOS SUN
# A.K. TRADERS SAT
# AARADHYA CANTEEN STATIONARY AND FOOD MART TUE
# AARADHYA CANTEEN STATIONERY & FOOD MART TUE
# ADYA STORE SAT
# AGGARAWAL DEPARTMENTAL STORE TUE
# AGGARWAL DEPARTMENT STORE SAT
# AGGARWAL FOOD PLAZA THU
# AGGARWAL KIRANA  AND GENERAL STORE THU
# AGGARWAL KIRANA STORE MON
# AGGARWAL PROVISION STORE SAT
# AGGARWAL SWEETS . OTH
# AGGARWAL TRADERS AI THU
# AGGARWAL TRADING CO TUE
# AGGAWAL TRADERS THU
# ALAM ENTERPRISES SUN
# AMIT TYAGI KIRANA MON
# AMRIT STORE THU
# ANANT WELLNESS MON
# ANGEL PROVISION STORE SAT
# ANSHIKA COSMATICS MON
# ANTARIKSH ENTERPRISES TUE
# APNA STORES THU
# APRITA ENTERPRISE TUE
# ARMAAN TELECOM MON
# ARN MEGAMART LLP SAT
# ARYAVART MEDICOS SAT
# ASHOK DAIRY THU
# BABLI KIRANA OTH
# BAJNA PANEER TUE
# BAJNA PANEER DAIRY TUE
# BAJRANG SHOPPING CENTRE THU
# BAKERS ZONE TUE
# BALAJI KIRANA STORE MON
# BALAJI PROVISION STORE. THU
# BANGALI KIRANA MON
# BANKE BIHARI TRADERS TUE
# BANSAL PROVISION STORE SAT
# ...

# %%
print(result)

# %%
for row in result:
    print(row)
# Out:
# (151, None, u'ANGEL PROVISION STORE', None, u'MARG', datetime.datetime(2018, 5, 30, 12, 35, 52, 742868))
# (81, None, u'GOYAL SUPERMART', None, u'MARG', datetime.datetime(2018, 5, 30, 12, 35, 52, 742868))
# (27, u'4254028', u'KUMAR PROVISION STORE', u'ALPHA I', u'MAR', datetime.datetime(2018, 5, 30, 12, 35, 52, 742868))
# (888, u'C001382815', u'NAVIN KIRANA STORE  GN', u'WED - OUTER', u'COL', datetime.datetime(2018, 5, 30, 12, 35, 52, 742868))
# (94, u'4254058', u'9 TO 9 MARCETOS', u'SOCIETY', u'MAR', datetime.datetime(2018, 5, 30, 12, 35, 52, 742868))
# (569, u'C001382786', u'PAPPY TRADERS', u'SAT SURAJ PUR', u'COL', datetime.datetime(2018, 5, 30, 12, 35, 52, 742868))
# (787, None, u'STAR GROCERY MART', None, u'MARG', datetime.datetime(2018, 5, 30, 12, 35, 52, 742868))
# (41, u'C001382734', u'KULDEEP KIRANA STORE', u'THU GAMMA ALPHA', u'COL', datetime.datetime(2018, 5, 30, 12, 35, 52, 742868))
# ...

# %%
result = engine.
